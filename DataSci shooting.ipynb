# %% [markdown]
# ชนม์ธนวัฒน์ แก้วกัณฑ์ 6421600042
# พัชรพล เลารุจิราลัย 6421600204

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /var/folders/0s/xxmc0n411b7_xmq9dlkn2slc0000gn/T/ipykernel_3733/265554930.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_csv('database.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2142 entries, 0 to 2141
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       2142 non-null   int64
#  1   name                     2123 non-null   object
#  2   date                     2142 non-null   object
#  3   manner_of_death          2142 non-null   object
#  4   armed                    2136 non-null   object
#  5   age                      2099 non-null   float64
#  6   gender                   2141 non-null   object
#  7   race                     2039 non-null   object
#  8   city                     2142 non-null   object
#  9   state                    2142 non-null   object
#  10  signs_of_mental_illness  2142 non-null   bool
#  11  threat_level             2142 non-null   object
#  12  flee                     2106 non-null   object
#  13  body_camera              2142 non-null   bool
# dtypes: bool(2), float64(1), int64(1), object(10)
# memory usage: 205.1+ KB

# %%
df = df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1986 entries, 0 to 2141
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       1986 non-null   int64
#  1   name                     1986 non-null   object
#  2   date                     1986 non-null   object
#  3   manner_of_death          1986 non-null   object
#  4   armed                    1986 non-null   object
#  5   age                      1986 non-null   float64
#  6   gender                   1986 non-null   object
#  7   race                     1986 non-null   object
#  8   city                     1986 non-null   object
#  9   state                    1986 non-null   object
#  10  signs_of_mental_illness  1986 non-null   bool
#  11  threat_level             1986 non-null   object
#  12  flee                     1986 non-null   object
#  13  body_camera              1986 non-null   bool
# dtypes: bool(2), float64(1), int64(1), object(10)
# memory usage: 205.6+ KB

# %%
df.head()
# Out:
#    id                name        date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  2015-01-02              shot         gun  53.0
# 1   4    Lewis Lee Lembke  2015-01-02              shot         gun  47.0
# 2   5  John Paul Quintero  2015-01-03  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman  2015-01-04              shot  toy weapon  32.0
# 4   9   Michael Rodriguez  2015-01-04              shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera
# 0  Not fleeing        False
# 1  Not fleeing        False
# 2  Not fleeing        False
# 3  Not fleeing        False
# 4  Not fleeing        False

# %%
def cutDay(date):
    return date[:7]

YMDate = df['date'].apply(cutDay)
df.insert(3, "YMDate",YMDate , True)
df.head()
# Out:
#    id                name        date   YMDate   manner_of_death       armed  \
# 0   3          Tim Elliot  2015-01-02  2015-01              shot         gun
# 1   4    Lewis Lee Lembke  2015-01-02  2015-01              shot         gun
# 2   5  John Paul Quintero  2015-01-03  2015-01  shot and Tasered     unarmed
# 3   8     Matthew Hoffman  2015-01-04  2015-01              shot  toy weapon
# 4   9   Michael Rodriguez  2015-01-04  2015-01              shot    nail gun
#
#     age gender race           city state  signs_of_mental_illness  \
# 0  53.0      M    A        Shelton    WA                     True
# 1  47.0      M    W          Aloha    OR                    False
# 2  23.0      M    H        Wichita    KS                    False
# 3  32.0      M    W  San Francisco    CA                     True
# 4  39.0      M    H          Evans    CO                    False
#
#   threat_level         flee  body_camera
# 0       attack  Not fleeing        False
# 1       attack  Not fleeing        False
# 2        other  Not fleeing        False
# 3       attack  Not fleeing        False
# 4       attack  Not fleeing        False

# %%
def cutY(date):
    return date[:4]

YDate = df['date'].apply(cutY)
df.insert(4, "YDate",YDate , True)
df.head()
# Out:
#    id                name        date   YMDate YDate   manner_of_death  \
# 0   3          Tim Elliot  2015-01-02  2015-01  2015              shot
# 1   4    Lewis Lee Lembke  2015-01-02  2015-01  2015              shot
# 2   5  John Paul Quintero  2015-01-03  2015-01  2015  shot and Tasered
# 3   8     Matthew Hoffman  2015-01-04  2015-01  2015              shot
# 4   9   Michael Rodriguez  2015-01-04  2015-01  2015              shot
#
#         armed   age gender race           city state  signs_of_mental_illness  \
# 0         gun  53.0      M    A        Shelton    WA                     True
# 1         gun  47.0      M    W          Aloha    OR                    False
# 2     unarmed  23.0      M    H        Wichita    KS                    False
# 3  toy weapon  32.0      M    W  San Francisco    CA                     True
# 4    nail gun  39.0      M    H          Evans    CO                    False
#
#   threat_level         flee  body_camera
# 0       attack  Not fleeing        False
# 1       attack  Not fleeing        False
# 2        other  Not fleeing        False
# 3       attack  Not fleeing        False
# 4       attack  Not fleeing        False

# %% [markdown]
# ### เริ่ม

# %%
print('Oldest date:', df['date'].min())
print('Latest date:', df['date'].max())
# Out:
# Oldest date: 2015-01-02
# Latest date: 2017-02-28

# %%
print('Mean age:', round(df['age'].mean()))
print('Min/Max age:', df['age'].min(),'/', df['age'].max())
# Out:
# Mean age: 36
# Min/Max age: 6.0 / 83.0

# %%
fig = plt.figure(figsize=(10,6))
sns.histplot(df['age'],bins=30)
plt.show()

# %%
df[df['age'] == df['age'].min()]
# Out:
#       id           name        date   YMDate YDate manner_of_death    armed  \
# 830  980  Jeremy Mardis  2015-11-03  2015-11  2015            shot  unarmed
#
#      age gender race        city state  signs_of_mental_illness threat_level  \
# 830  6.0      M    W  Marksville    LA                    False        other
#
#     flee  body_camera
# 830  Car         True

# %%
df[df['age'] == df['age'].max()]
# Out:
#         id                 name        date   YMDate YDate manner_of_death  \
# 275    357  Richard Dale Weaver  2015-04-12  2015-04  2015            shot
# 1878  2095     Quinton Phillips  2016-12-01  2016-12  2016            shot
#
#         armed   age gender race           city state  signs_of_mental_illness  \
# 275   machete  83.0      M    W  Oklahoma City    OK                     True
# 1878      gun  83.0      M    W          Dover    AR                    False
#
#      threat_level         flee  body_camera
# 275         other  Not fleeing        False
# 1878       attack  Not fleeing        False

# %%
# index = ['Asian', 'Black', 'Hispanic', 'Nat Amer.', 'White']
sns.histplot(data=df, x="race", multiple="dodge", shrink=.8)
# Out:
# <Axes: xlabel='race', ylabel='Count'>

# %%
platform_counts = df.value_counts('race')
platform_counts
# Out:
# race
# W    1022
# B     523
# H     355
# A      32
# O      28
# N      26
# Name: count, dtype: int64

# %%
# index = ['Asian', 'Black', 'Hispanic', 'Nat Amer.', 'White']
# พล็อต Pie chart
plt.figure(figsize=(8, 6))
plt.pie(platform_counts, labels=platform_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Population Distribution by Platform')
plt.legend(['White','Black', 'Hispanic', 'Asian', 'Other','Nat Amer.'])
plt.show()

# %%
sns.histplot(data=df, x="YDate", hue= 'body_camera', multiple="dodge", shrink=.8)
# Out:
# <Axes: xlabel='YDate', ylabel='Count'>

# %%
sns.histplot(data=df, x="YDate", hue= 'race', multiple="dodge", shrink=.8)
# Out:
# <Axes: xlabel='YDate', ylabel='Count'>

# %%
sns.histplot(data=df, x="YDate", hue= 'flee', multiple="dodge", shrink=.8)
# Out:
# <Axes: xlabel='YDate', ylabel='Count'>

# %%
sns.histplot(data=df, x="threat_level", hue= 'flee', multiple="dodge", shrink=.8)
# Out:
# <Axes: xlabel='threat_level', ylabel='Count'>

# %%
df['armed'].value_counts()[:10]
# Out:
# armed
# gun               1094
# knife              290
# unarmed            151
# vehicle            128
# undetermined        90
# toy weapon          90
# machete             15
# unknown weapon      11
# sword                8
# hammer               7
# Name: count, dtype: int64

# %%
fig = plt.figure(figsize=(12,6))
sns.countplot(x='armed', data=df[df['armed'].map(df['armed'].value_counts()) > 30], hue='race')
plt.show()

# %%
fig, axes = plt.subplots( ncols = 2, nrows = 2 )
df[df['flee'] == 'Car'].value_counts('armed')[:10].plot(kind='barh' , ax=axes[0,0] , title='Car')
df[df['flee'] == 'Not fleeing'].value_counts('armed')[:10].plot(kind='barh' , ax=axes[0,1] , title='Not fleeing')
df[df['flee'] == 'Foot'].value_counts('armed')[:10].plot(kind='barh' , ax=axes[1,0] , title='Foot')
df[df['flee'] == 'Other'].value_counts('armed')[:10].plot(kind='barh' , ax=axes[1,1] , title='Other')
plt.suptitle("s")
fig.tight_layout()
